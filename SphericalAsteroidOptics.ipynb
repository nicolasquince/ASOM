# %%
import numpy as np

# Declaration of data
R = 25                                      # [m]
D = 0.1                                     # [m]
f = 0.7                                     # [m]
lamb = 5e-7                                 # [m]
c = 3e8                                     # [m/s]
Aalb = 0.12                                 # [-]
r = 0.5                                     # [m]
V = 1e3                                     # [m/s]
Dx = 5e-6                                   # [m]
Isun = 1000                                 # [W/m^2]
NEP = 1e3                                   # [W/Hz^(1/2)]
nu = 400e12                                 # [Hz]
eta = 2                                     # [-]
nmax = 1024                                 # [#]

# Constraining h
h = (r*D)/(lamb)                            # [m]

# Additional checks
Fc = (Aalb*Isun/16)*(D/f)**2                # [W/m^2]
NEI = eta*NEP/(nu*np.pi*(D/2)**2)           # [W/m^2]
n = 2*R/r                                   # [#]
S = nmax*Dx                                 # [m]

# Constraining texposure
texp = (h/V/f)*np.sqrt(Dx**2-(lamb*f/D)**2) # [s]

# Printing of results
(h/1e3,texp*1e3)                            # [km,ms]
# Out:
# (100.00000000000001, 0.5101020306102039)
